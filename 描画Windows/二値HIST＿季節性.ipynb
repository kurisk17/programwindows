# %%
import pandas as pd
import numpy as np
import os
import datetime as dt
import calendar
from matplotlib import pyplot as plt
import scipy.stats as stats
import glob

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

from mpl_toolkits.mplot3d import Axes3D  #3Dplot
import seaborn as sns
import japanize_matplotlib


from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

from matplotlib.ticker import ScalarFormatter
import matplotlib.ticker as ptick ##これが必要！

# %%
files = glob.glob('../../../卒論関連書類/データ/king_history/king_history1/*')
version = len(files)-1
df_king =pd.read_csv(f'../../../卒論関連書類/データ/king_history/king_history1/king{version}.csv',converters={'DateTime':pd.to_datetime})

# %%
# 平均をグラフに追加している
def changePLOT_HIST_oneyear(name,value0,value1,times,year):
    plt.rcParams['font.family'] = 'Times New Roman'

    fig = plt.figure(figsize=(5,5))
    ax1= fig.subplots()
    ax1.hist(value0,bins=100,color='black',alpha=0.8,label='価格差がないとき')
    ax1.hist(value1,bins =100,color='gray',alpha=0.8,label='価格差があるとき')

    ax1.legend(prop ={'family':'MS Mincho'})

    title = f'{times[0]} - {times[-1]}'
    plt.title(title)
    ax1.xaxis.set_major_formatter(ptick.ScalarFormatter(useMathText=True))
    # 軸の桁数を設定
    axe_num = len(str(int(ax1.get_xticks()[-1])))-2
    ax1.ticklabel_format(style="sci", axis="x", scilimits=(axe_num,axe_num)) 

    ax1.set_xlabel(name,fontname='MS Mincho')

    ax1.axvline(value0.mean(),label= '価格差がない方の平均値',color='b',alpha=0.5)
    ax1.axvline(value1.mean(),label= '価格差がある方の平均値',color='r',alpha=0.5)
    ax1.legend(prop ={'family':'MS Mincho'})
    plt.savefig(f'../../../卒論関連書類/画像/3章画像/分析結果画像/二値HIST/各年＿平均値付き/{year}_{name}_HIST.png')


    plt.show()

def NenDogotoPLOT_HIST_oneyear(name,value0,value1,times,year):
    plt.rcParams['font.family'] = 'Times New Roman'

    fig = plt.figure(figsize=(5,5))
    ax1= fig.subplots()
    ax1.hist(value0,bins=100,color='black',alpha=0.8,label='価格差がないとき')
    ax1.hist(value1,bins =100,color='gray',alpha=0.8,label='価格差があるとき')

    ax1.legend(prop ={'family':'MS Mincho'})

    title = f'{times[0]} - {times[-1]}'
    plt.title(title)
    ax1.xaxis.set_major_formatter(ptick.ScalarFormatter(useMathText=True))
    # 軸の桁数を設定
    axe_num = len(str(int(ax1.get_xticks()[-1])))-2
    ax1.ticklabel_format(style="sci", axis="x", scilimits=(axe_num,axe_num)) 

    ax1.set_xlabel(name,fontname='MS Mincho')

    ax1.axvline(value0.mean(),label= '価格差がない方の平均値',color='b',alpha=0.5)
    ax1.axvline(value1.mean(),label= '価格差がある方の平均値',color='r',alpha=0.5)
    ax1.legend(prop ={'family':'MS Mincho'})
    plt.savefig(f'../../../卒論関連書類/画像/3章画像/分析結果画像/二値HIST/年度ごと平均値つき/{year}年度_{name}_HIST.png')


    plt.show()

# %%
#年度ごと
cols = ['DateTime', 'gap_price[intra-spot](円/kWh)','低下量合計', '停止・低下ユニット数合計','intra_volume（MWh/h）','spot_volume(kWh)', '太陽光絶対値誤差合算(実績-想定)(kWh)',
       '風力絶対値誤差合算(実績-想定)(kWh)']

df_select = df_king[cols]

re_col = ['DateTime', '価格差 (時間前市場 - スポット市場) (Yen/kWh)','出力低下量合計 (kW)', '停止・低下ユニット数合計 (基)','時間前市場取引量 (kWh)','スポット市場取引量 (kWh)', '太陽光誤差(実績-想定)合算 (kWh)',
       '風力誤差(実績-想定)合算値 (kWh)'
    #    , 'エリア毎の広域予備率の平均値(%)'
       ]
df_select.columns = re_col
df_select['時間前市場取引量 (kWh)'] =df_select['時間前市場取引量 (kWh)']*1000/2

percent =50
# これは各年

for year in range(2018,2023):

# for year in range(2022,2023):
# year=2018
    start_point = dt.datetime(year,4,1,0,0)
    end_point = dt.datetime(year+1,3,31,23,30)

    # まず、データがある分すべての相関をとる。
    target =re_col[2:]
    for name in target:
        df = df_select[['DateTime', '価格差 (時間前市場 - スポット市場) (Yen/kWh)',name]]
        df = df[(df['DateTime']>=start_point)&(df['DateTime']<=end_point)].dropna()


        df['judge'] =0

        df['価格差 (時間前市場 - スポット市場) (Yen/kWh)'] =abs(df['価格差 (時間前市場 - スポット市場) (Yen/kWh)'])
        judge_line = np.percentile(df['価格差 (時間前市場 - スポット市場) (Yen/kWh)'],percent)

        df.loc[df['価格差 (時間前市場 - スポット市場) (Yen/kWh)']>judge_line,['judge']] =1

        value0 = df[df['judge']==0][name].values
        value1 = df[df['judge']==1][name].values
        times =df['DateTime'].dt.date.values
        NenDogotoPLOT_HIST_oneyear(name,value0,value1,times,year)
        print(f'ない方の平均値{round(value0.mean(),3)}、あるほうの平均値{round(value1.mean(),3)}')
# Out:
# C:\Users\Annex Rakyu\AppData\Local\Temp\ipykernel_9676\2255686717.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_select['時間前市場取引量 (kWh)'] =df_select['時間前市場取引量 (kWh)']*1000/2
# ない方の平均値66186352.805、あるほうの平均値62073947.912
# ない方の平均値171.678、あるほうの平均値161.707
# ない方の平均値79858.661、あるほうの平均値121122.511
# ない方の平均値11896507.72、あるほうの平均値12358254.826
# ない方の平均値437851.904、あるほうの平均値461140.393
# ない方の平均値48897.884、あるほうの平均値50633.998
# ない方の平均値55184766.053、あるほうの平均値56976208.898
# ない方の平均値157.952、あるほうの平均値161.998
# ない方の平均値129970.392、あるほうの平均値163809.848
# ない方の平均値16689460.33、あるほうの平均値16610760.777
# ない方の平均値435465.664、あるほうの平均値444529.392
# ない方の平均値48267.056、あるほうの平均値47665.332
# ない方の平均値49553048.675、あるほうの平均値54306016.038
# ない方の平均値133.603、あるほうの平均値145.543
# ない方の平均値187960.664、あるほうの平均値271124.897
# ない方の平均値17884688.425、あるほうの平均値17827300.109
# ない方の平均値392849.761、あるほうの平均値399673.655
# ない方の平均値46218.023、あるほうの平均値49040.051
# ない方の平均値42252980.277、あるほうの平均値41437822.448
# ない方の平均値106.245、あるほうの平均値103.175
# ない方の平均値204985.006、あるほうの平均値271709.609
# ない方の平均値18526761.688、あるほうの平均値18818709.889
# ない方の平均値364315.025、あるほうの平均値332127.017
# ない方の平均値47448.555、あるほうの平均値53454.926
# ない方の平均値48893435.226、あるほうの平均値45771257.291
# ない方の平均値124.994、あるほうの平均値116.968
# ない方の平均値233547.845、あるほうの平均値303756.335
# ない方の平均値17131531.999、あるほうの平均値18190188.256
# ない方の平均値355239.593、あるほうの平均値514002.949
# ない方の平均値50392.996、あるほうの平均値50464.159

# %%
#１年毎正式版
cols = ['DateTime', 'gap_price[intra-spot](円/kWh)','低下量合計', '停止・低下ユニット数合計','intra_volume（MWh/h）','spot_volume(kWh)', '太陽光絶対値誤差合算(実績-想定)(kWh)',
       '風力絶対値誤差合算(実績-想定)(kWh)']

df_select = df_king[cols]

re_col = ['DateTime', '価格差 (時間前市場 - スポット市場) (Yen/kWh)','出力低下量合計 (kW)', '停止・低下ユニット数合計 (基)','時間前市場取引量 (kWh)','スポット市場取引量 (kWh)', '太陽光誤差(実績-想定)合算 (kWh)',
       '風力誤差(実績-想定)合算値 (kWh)'
    #    , 'エリア毎の広域予備率の平均値(%)'
       ]
df_select.columns = re_col
df_select['時間前市場取引量 (kWh)'] =df_select['時間前市場取引量 (kWh)']*1000/2

percent =50
# これは各年

for year in range(2018,2023):

# for year in range(2022,2023):
# year=2018
    start_point = dt.datetime(year,1,1,0,0)
    end_point = dt.datetime(year,12,31,23,30)

    # まず、データがある分すべての相関をとる。
    target =re_col[2:]
    for name in target:
        df = df_select[['DateTime', '価格差 (時間前市場 - スポット市場) (Yen/kWh)',name]]
        df = df[(df['DateTime']>=start_point)&(df['DateTime']<=end_point)].dropna()


        df['judge'] =0

        df['価格差 (時間前市場 - スポット市場) (Yen/kWh)'] =abs(df['価格差 (時間前市場 - スポット市場) (Yen/kWh)'])
        judge_line = np.percentile(df['価格差 (時間前市場 - スポット市場) (Yen/kWh)'],percent)

        df.loc[df['価格差 (時間前市場 - スポット市場) (Yen/kWh)']>judge_line,['judge']] =1

        value0 = df[df['judge']==0][name].values
        value1 = df[df['judge']==1][name].values
        times =df['DateTime'].dt.date.values
        changePLOT_HIST_oneyear(name,value0,value1,times,year)
        print(f'ない方の平均値{round(value0.mean(),3)}、あるほうの平均値{round(value1.mean(),3)}')
# Out:
# C:\Users\Annex Rakyu\AppData\Local\Temp\ipykernel_9676\3417497728.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_select['時間前市場取引量 (kWh)'] =df_select['時間前市場取引量 (kWh)']*1000/2
# ない方の平均値71511962.482、あるほうの平均値66106390.551
# ない方の平均値186.297、あるほうの平均値173.191
# ない方の平均値86406.876、あるほうの平均値135293.935
# ない方の平均値10601731.962、あるほうの平均値11185828.884
# ない方の平均値459510.58、あるほうの平均値460958.327
# ない方の平均値47007.511、あるほうの平均値49515.188
# ない方の平均値54500112.841、あるほうの平均値54935095.526
# ない方の平均値151.692、あるほうの平均値151.063
# ない方の平均値104381.421、あるほうの平均値139545.696
# ない方の平均値16263707.083、あるほうの平均値16313241.787
# ない方の平均値434628.186、あるほうの平均値455065.719
# ない方の平均値47987.754、あるほうの平均値47642.982
# ない方の平均値51970717.991、あるほうの平均値56118824.723
# ない方の平均値144.109、あるほうの平均値155.172
# ない方の平均値188810.746、あるほうの平均値258336.09
# ない方の平均値17643144.593、あるほうの平均値17509151.453
# ない方の平均値392009.313、あるほうの平均値414330.561
# ない方の平均値46782.813、あるほうの平均値48829.27
# ない方の平均値42228264.76、あるほうの平均値45067159.734
# ない方の平均値106.972、あるほうの平均値113.432
# ない方の平均値181986.511、あるほうの平均値246056.869
# ない方の平均値18558190.945、あるほうの平均値18556891.044
# ない方の平均値382963.339、あるほうの平均値350529.777
# ない方の平均値47633.918、あるほうの平均値51459.236
# ない方の平均値46077942.256、あるほうの平均値44147211.306
# ない方の平均値116.986、あるほうの平均値112.203
# ない方の平均値240756.463、あるほうの平均値305129.199
# ない方の平均値17619710.361、あるほうの平均値18427333.966
# ない方の平均値298502.355、あるほうの平均値476638.166
# ない方の平均値53311.01、あるほうの平均値52672.391

# %%
df_select
# Out:
#                  DateTime  価格差 (時間前市場 - スポット市場) (Yen/kWh)  出力低下量合計 (kW)  \
# 0     2018-04-01 00:00:00                            0.32    53484820.0
# 1     2018-04-01 00:30:00                            0.59   102677262.0
# 2     2018-04-01 01:00:00                            0.72   100007262.0
# 3     2018-04-01 01:30:00                            0.72   100007262.0
# 4     2018-04-01 02:00:00                           -0.03   100007262.0
# ...                   ...                             ...           ...
# 84410 2023-01-05 21:30:00                             NaN    57207370.0
# 84411 2023-01-05 22:00:00                             NaN    57207370.0
# 84412 2023-01-05 22:30:00                             NaN    57207370.0
# 84413 2023-01-05 23:00:00                             NaN    57632370.0
# 84414 2023-01-05 23:30:00                             NaN    41303360.0
#
#        停止・低下ユニット数合計 (基)  時間前市場取引量 (kWh)  スポット市場取引量 (kWh)  \
# 0                 126.0         29400.0          6098500
# 1                 255.0         27000.0          6225500
# 2                 255.0         28650.0          6356500
# 3                 255.0         31500.0          6439500
# 4                 255.0         30800.0          6439000
# ...                 ...             ...              ...
# 84410             157.0             NaN         22544600
# 84411             157.0             NaN         22180900
# 84412             157.0             NaN         22143700
# 84413             159.0             NaN         22054200
# 84414             128.0             NaN         20802700
#
#        太陽光誤差(実績-想定)合算 (kWh)  風力誤差(実績-想定)合算値 (kWh)
# 0                       0.0             15893.195
# 1                       0.0             17701.670
# 2                       0.0             19567.870
# 3                       0.0             21212.950
# 4                       0.0             23300.435
# ...                     ...                   ...
# 84410                   NaN                   NaN
# 84411                   NaN                   NaN
# 84412                   NaN                   NaN
# 84413                   NaN                   NaN
# 84414                   NaN                   NaN
#
# [84415 rows x 8 columns]

# %%
# 夏をやってみたがとりたてた変化はなし
# 広域予備率なし
cols = ['DateTime', 'gap_price[intra-spot](円/kWh)','低下量合計', '停止・低下ユニット数合計','intra_volume（MWh/h）','spot_volume(kWh)', '太陽光絶対値誤差合算(実績-想定)(kWh)',
       '風力絶対値誤差合算(実績-想定)(kWh)']

df_select = df_king[cols].dropna()

re_col = ['DateTime', '価格差 (時間前市場 - スポット市場) (Yen/kWh)','出力低下量合計 (kW)', '停止・低下ユニット数合計 (基)','時間前市場取引量 (kWh)','スポット市場取引量 (kWh)', '太陽光誤差(実績-想定)合算 (kWh)',
       '風力誤差(実績-想定)合算値 (kWh)'
    #    , 'エリア毎の広域予備率の平均値(%)'
       ]
df_select.columns = re_col
df_select['時間前市場取引量 (kWh)'] =df_select['時間前市場取引量 (kWh)']*1000/2

percent =50
# これは各年

for year in range(2018,2023):
# year=2018
    start_point = dt.datetime(year,1,1,0,0)
    end_point = dt.datetime(year,12,31,23,30)
    df = df_select[(df_select['DateTime']>=start_point)&(df_select['DateTime']<=end_point)].dropna()
    # 夏だけ
    df = df[(df['DateTime'].dt.month>=4)&(df['DateTime'].dt.month<=9)]

    df['judge'] =0

    df['価格差 (時間前市場 - スポット市場) (Yen/kWh)'] =abs(df['価格差 (時間前市場 - スポット市場) (Yen/kWh)'])
    judge_line = np.percentile(df['価格差 (時間前市場 - スポット市場) (Yen/kWh)'],percent)

    df.loc[df['価格差 (時間前市場 - スポット市場) (Yen/kWh)']>judge_line,['judge']] =1
    # まず、データがある分すべての相関をとる。
    target =re_col[2:]
    for name in target:
        value0 = df[df['judge']==0][name].values
        value1 = df[df['judge']==1][name].values
        times =df['DateTime'].dt.date.values
        changePLOT_HIST_oneyear(name,value0,value1,times,year)
        print(f'ない方の平均値{round(value0.mean(),3)}、あるほうの平均値{round(value1.mean(),3)}')
# Out:
# ない方の平均値77924861.507、あるほうの平均値71735986.479
# ない方の平均値201.9、あるほうの平均値187.529
# ない方の平均値80562.407、あるほうの平均値141645.763
# ない方の平均値8415843.023、あるほうの平均値8705695.075
# ない方の平均値450495.148、あるほうの平均値451402.527
# ない方の平均値45801.943、あるほうの平均値49288.759
# ない方の平均値51311996.228、あるほうの平均値53491444.555
# ない方の平均値141.387、あるほうの平均値145.44
# ない方の平均値107262.352、あるほうの平均値158952.042
# ない方の平均値16145018.511、あるほうの平均値16376338.914
# ない方の平均値510683.103、あるほうの平均値525943.661
# ない方の平均値43881.169、あるほうの平均値43225.484
# ない方の平均値55337221.86、あるほうの平均値60293148.267
# ない方の平均値150.758、あるほうの平均値164.536
# ない方の平均値237291.529、あるほうの平均値309658.904
# ない方の平均値17688770.487、あるほうの平均値17172937.308
# ない方の平均値403186.895、あるほうの平均値460969.082
# ない方の平均値43617.21、あるほうの平均値44800.883
# ない方の平均値42738256.761、あるほうの平均値43160769.007
# ない方の平均値107.869、あるほうの平均値108.813
# ない方の平均値184910.989、あるほうの平均値229010.625
# ない方の平均値18542863.416、あるほうの平均値18776181.1
# ない方の平均値410035.038、あるほうの平均値436518.865
# ない方の平均値44109.585、あるほうの平均値46067.668
# ない方の平均値48907368.12、あるほうの平均値45037024.173
# ない方の平均値122.632、あるほうの平均値112.083
# ない方の平均値233063.014、あるほうの平均値314430.422
# ない方の平均値16637617.822、あるほうの平均値18329881.403
# ない方の平均値355239.593、あるほうの平均値514002.949
# ない方の平均値50392.996、あるほうの平均値50464.159
